# %%
from numpy import *
from matplotlib.pyplot import *
% matplotlib inline

# %%
#Datos:
t11 = array([0.0,30.0,60.0,90.0,120.0,150.0,180.0,210.0,240.0,270.0,300.0,330.0,360.0,390.0,420.0,450.0,480.0,510.0,540.0,570.0,600.0])
v11 = array([5.02,4.46,3.96,3.53,3.15,2.81,2.51,2.25,2.02,1.82,1.63,1.47,1.33,1.21,1.09,1.00,0.91,0.83,0.76,0.70,0.64,0.59,0.55,0.50])

t12 = array([0.0,30.0,60.0,90.0,120.0,150.0,180.0,210.0,240.0,270.0,300.0,330.0,360.0,390.0,420.0,450.0,480.0,510.0,540.0,570.0,600.0,620.0])
v12 = array([5.02,4.44,3.93,3.48,3.07,2.73,2.43,2.16,1.92,1.71,1.53,1.37,1.22,1.10,0.98,0.88,0.80,0.72,0.65,0.59,0.54,0.50])

t13 =  array([0.0,30.0,60.0,90.0,120.0,150.0,180.0,210.0,240.0,270.0,300.0,330.0,360.0,390.0,420.0,450.0,480.0,510.0,540.0,570.0,600.0])
v13 = array([4.91,4.37,3.85,3.41,3.00,2.67,2.37,2.10,1.87,1.65,1.48,1.31,1.17,1.05,0.94,0.84,0.75,0.67,0.61,0.55,0.49])

# %%
#Grafico Escala "Normal":
#scatter(t11,v11,color='red')
scatter(t12,v12,color='blue')
scatter(t13,v13,color='green')
title('Voltaje v/s Tiempo')
xlabel(r'$t$')
ylabel(r'$V$')
grid()

# %%
#Grafico Escala Semi-Logaritmica:
#scatter(t11,v11,color='red')
scatter(t12,v12,color='blue')
scatter(t13,v13,color='green')
title('ln(V) v/s Tiempo')
xlabel(r'$t$')
ylabel(r'$ln(V)$')
grid()
yscale('log')

# %%
#Ajuste de Curvas:
#z1 = polyfit(t11,log(v11),1)
z2 = polyfit(t12,log(v12),1)
z3 = polyfit(t13,log(v13),1)

# %%
#T11 = linspace(0,310,1000)
#V11 = e**(z1[1] + z1[0]*T11)

T12 = linspace(0,620,1000)
V12 = e**(z2[1] + z2[0]*T12)

T13 = linspace(0,600,1000)
V13 = e**(z3[1] + z3[0]*T13)

# %%
#Grafico Escala Semi-Logaritmica:
#scatter(t11,v11,color='red')
scatter(t12,v12,color='blue')
scatter(t13,v13,color='green')
#plot(T11,V11,color='red')
plot(T12,V12,color='blue')
plot(T13,V13,color='green')
title('ln(V) v/s Tiempo')
xlabel(r'$t$')
ylabel(r'$ln(V)$')
grid()
yscale('log')

# %%
#Grafico Escala "Normal":
#scatter(t11,v11,color='red')
scatter(t12,v12,color='blue')
scatter(t13,v13,color='green')
#plot(T11,V11,color='red')
plot(T12,V12,color='blue')
plot(T13,V13,color='green')
title('Voltaje v/s Tiempo')
xlabel(r'$t$')
ylabel(r'$V$')
grid()

# %%
#Coeficientes:
print(z2,z3)
# Out:
# [-0.00371954  1.56811834] [-0.00384744  1.56333078]
